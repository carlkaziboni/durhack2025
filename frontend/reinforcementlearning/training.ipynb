# %%
import pandas as pd
import numpy as np

# %%
# Look at headings of the dataset
df = pd.read_csv("12/01.csv")
df.columns
# Out:
# /var/folders/gt/v2b3tmpx1ylfjtn6js5pvrb00000gn/T/ipykernel_88438/3765449228.py:2: DtypeWarning: Columns (22,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("12/01.csv")
# Index(['CARRIER', 'CARRIER_CD_ICAO', 'FLTNO', 'FLTSUFFX', 'DEPAPT',
#        'DEP_PORT_CD_ICAO', 'DEPTERM', 'DEPCITY', 'DEPCTRY', 'ARRAPT',
#        'ARR_PORT_CD_ICAO', 'ARRTERM', 'ARRCITY', 'ARRCTRY', 'DEPTIM',
#        'SCHEDULED_DEPARTURE_TIME_UTC', 'SCHEDULED_DEPARTURE_DATE_TIME_LOCAL',
#        'SCHEDULED_DEPARTURE_DATE_TIME_UTC', 'ARRTIM',
#        'SCHEDULED_ARRIVAL_TIME_UTC', 'SCHEDULED_ARRIVAL_DATE_TIME_LOCAL',
#        'SCHEDULED_ARRIVAL_DATE_TIME_UTC', 'ARRDAY', 'ELPTIM', 'FLIGHT_DATE',
#        'SCHEDULED_DEPARTURE_DATE_UTC', 'SCHEDULED_ARRIVAL_DATE_LOCAL',
#        'SCHEDULED_ARRIVAL_DATE_UTC', 'STOPS', 'GENACFT', 'INPACFT',
#        'EQUIPMENT_CD_ICAO', 'ACFTCHANGE', 'SERVICE', 'PX', 'MEALS', 'FRTCLASS',
# ...
